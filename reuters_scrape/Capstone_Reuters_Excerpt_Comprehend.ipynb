# %% [markdown]
# # Reuters Archives - Amazon Comprehend (NLP and Text Analytics)

# %% [markdown]
# **Objectives:**
# 1. Use Amazon Comprehend for Topic Modeling and Sentiment Analysis
# https://docs.aws.amazon.com/comprehend/latest/dg/getting-started.html
# - Sentiment Analysis - https://docs.aws.amazon.com/comprehend/latest/dg/how-sentiment.html
# - Topic Modeling - https://docs.aws.amazon.com/comprehend/latest/dg/topic-modeling.html

# %% [markdown]
# - The Reuters dataset used here "reuters_data.csv" was web scraped from https://uk.reuters.com/news/archive/GCA-ForeignExchange on Dec 2, 2018. It contains...
# - articles from 2010-05-17 to 2018-11-30
# - 10,200 total articles
# - Index([u'Date', u'Timestamp', u'excerpt', u'link', u'page', u'post', u'title'], dtype='object')

# %%
import boto3
import botocore

# %%
Bucket = "capstoneproject-770851433061"
Key = "reuters_data_with_location.csv" #"Name of the file in S3 that you want to download"
outPutName = "reuters_data_with_location.csv" #The name you want to save after we download from s3
s3 = boto3.resource('s3')
try:
    s3.Bucket(Bucket).download_file(Key, outPutName)
except botocore.exceptions.ClientError as e:
    if e.response['Error']['Code'] == "404":
        print("The object does not exist.")
    else:
        raise

# %%
python -m pip install --user nltk #python2

# %% [markdown]
# # Objective 1. Topic Modeling and Sentiment Analysis on Article Excerpts

# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd
df = pd.read_csv('./data/reuters_data.csv')

# %%
df.excerpt[1]
# Out:
# 'Sterling slumped against the dollar and the euro on Tuesday as doubts grew about whether British Prime Minister Theresa May can get a Brexit agreement through a divided parliament.'

# %%
#get excerpts
reuters_excerpt = df.excerpt[:]
reuters_excerpt.head()
# Out:
# 0    The U.S. dollar gained on Tuesday after Federa...
# 1    Sterling slumped against the dollar and the eu...
# 2    Sterling gave up most of its earlier gains and...
# 3    The dollar tumbled from two-week highs on Wedn...
# 4    The pound fell towards a two-week low on Thurs...
# Name: excerpt, dtype: object

# %%
reuters_excerpt.to_csv('./data/reuters_excerpt.csv')

# %%
with open("reuters_excerpt.txt", "w") as my_output_file:
    [my_output_file.write("".join(row)+'\n') for row in reuters_excerpt]
my_output_file.close()

# %%
#import io
#with open("reuters_excerpt.txt",'r') as f:
#    text = f.read()
# process Unicode text
#with io.open("reuters_excerpt_utf.txt",'w',encoding='utf8') as f:
#    f.write(text)

# %% [markdown]
# ## Submit to Amazon Comprehend for Topic Modeling and Sentiment
# ### grab output files from Topic Modeling

# %%
topic_terms = pd.read_csv('./data/excerpt-topic-terms.csv')
doc_topics = pd.read_csv('./data/excerpt-doc-topics.csv')

# %%
topic_terms.head()
# Out:
#    topic      term    weight
# 0      0  investor  0.017498
# 1      0  national  0.000737
# 2      0      opec  0.000701
# 3      0  capítulo  0.000558
# 4      0     swiss  0.000889

# %%
#import re
doc_topics['docname'] = doc_topics['docname'].apply(lambda x: re.sub('reuters_excerpt.csv:', '', x))
doc_topics.docname = pd.to_numeric(doc_topics.docname)
doc_topics = doc_topics.sort_values('docname')

# %%
doc_topics= doc_topics.reset_index()
doc_topics.topic.head()
# Out:
# 0    12
# 1     2
# 2    19
# 3    19
# 4    19
# Name: topic, dtype: int64

# %%
len(doc_topics.topic.unique())
# Out:
# 20

# %%
doc_topics.groupby('topic')["proportion"].count()
# Out:
# topic
# 0      193
# 1        9
# 2     1754
# 3       66
# 4     1768
# 5       69
# 6       72
# 7        2
# 8        7
# 9     1193
# 10    1529
# 11       1
# 12      42
# 13    1761
# 14       2
# 16     425
# 17       2
# 19     896
# 22     373
# 23      38
# Name: proportion, dtype: int64

# %%
from collections import defaultdict

# %%
#cluster_groups = kmeans.predict(ret2.T)
#set(cluster_groups)
#print(cluster_groups)
#print(list(zip(cluster_groups, ret2.columns)))

# %%
topic = topic_terms['topic']
term = topic_terms['term']
#set(list(topic))
#print(list(topic))
print (list(zip(topic, term)))
# Out:
# [(0, 'investor'), (0, 'national'), (0, 'opec'), (0, 'cap\xc3\xadtulo'), (0, 'swiss'), (0, 'member'), (0, 'scrap'), (0, 'revive'), (0, 'fight'), (0, 'snb'), (1, 'friday'), (1, 'wednesday'), (1, 'thursday'), (1, 'tuesday'), (1, 'monday'), (1, 'saturday'), (1, 'sunday'), (1, 'strategist'), (1, 'road'), (1, 'prove'), (2, 'euro'), (2, 'zone'), (2, 'debt'), (2, 'crisis'), (2, 'government'), (2, 'bond'), (2, 'greece'), (2, 'investor'), (2, 'market'), (2, 'european'), (3, 'bank'), (3, 'union'), (3, 'share'), (3, "bank's"), (3, 'company'), (3, 'opec'), (3, 'group'), (3, 'producer'), (3, 'banker'), (3, 'glut'), (4, 'yen'), (4, 'dollar'), (4, 'bank'), (4, 'monetary'), (4, 'japanese'), (4, 'japan'), (4, 'policy'), (4, 'minister'), (4, 'currency'), (4, 'low'), (5, 'u.s'), (5, 'britain'), (5, 'uk'), (5, 'union'), (5, 'export'), (5, 'mine'), (5, 'russian'), (5, 'brexit'), (5, 'energy'), (5, 'metal'), (6, 'dollar'), (6, 'ftse'), (6, 'share'), (6, 'brent'), (6, 'weight'), (6, 'bitcoin'), (6, 'barrel'), (6, 'international'), (6, 'crude'), (6, 'miner'), (7, 'interest'), (7, 'credit'), (7, 'top'), (7, 'downgrade'), (7, 'sovereign'), (7, 'iran'), (7, "moody's"), (7, 'lend'), (7, 'telecom'), (7, 'deposit'), (8, 'rate'), (8, 'bill'), (8, 'pick'), (8, 'barrel'), (8, 'issue'), (8, 'retailer'), (8, 'hsbc'), (8, 'telecom'), (8, 'development'), (8, 'direct'), (9, 'dollar'), (9, 'show'), (9, 'sterling'), (9, 'u.s'), (9, 'month'), (9, 'datar'), (9, 'euro'), (9, 'rise'), (9, 'year'), (9, 'expect'), (10, 'yuan'), (10, 'exchange'), (10, 'foreign'), (10, "china's"), (10, 'bank'), (10, 'currency'), (10, 'central'), (10, 'chino'), (10, 'market'), (10, 'trade'), (11, 'primar'), (11, 'market'), (11, 'theresa'), (11, 'referendum'), (11, 'trough'), (11, "may's"), (11, 'parliament'), (11, 'narrow'), (11, 'aid'), (11, 'parliamentary'), (12, 'european'), (12, 'index'), (12, 'top'), (12, 'janet'), (12, 'chair'), (12, 'yellen'), (12, 'world'), (12, 'treasury'), (12, 'trump'), (12, "reserve's"), (13, 'stock'), (13, 'u.s'), (13, 'global'), (13, 'market'), (13, 'equity'), (13, 'investor'), (13, 'fall'), (13, 'rise'), (13, 'price'), (13, 'world'), (14, 'datar'), (14, 'president'), (14, 'report'), (14, 'sanction'), (14, 'poll'), (14, 'donald'), (14, 'survey'), (14, 'avert'), (14, 'result'), (14, 'announce'), (15, 'fall'), (15, 'high'), (15, 'languish'), (15, 'slide'), (15, 'wait'), (15, 'skid'), (15, 'plunge'), (15, 'million'), (15, 'wallow'), (15, 'sink'), (16, 'dollar'), (16, 'u.s'), (16, 'week'), (16, 'high'), (16, 'month'), (16, 'euro'), (16, 'basket'), (16, 'currency'), (16, 'friday'), (16, 'year'), (17, 'reservar'), (17, "reserve's"), (17, 'billion'), (17, 'regulator'), (17, 'midpoint'), (17, 'finance'), (17, 'account'), (17, 'meeting'), (17, 'primar'), (17, 'executive'), (18, 'currency'), (18, 'financial'), (18, 'share'), (18, 'equity'), (18, 'theresa'), (18, 'security'), (18, "currency's"), (18, 'source'), (18, 'europe'), (18, 'executive'), (19, 'bank'), (19, 'rate'), (19, 'interest'), (19, 'sterling'), (19, 'england'), (19, 'rise'), (19, 'low'), (19, 'dollar'), (19, 'high'), (19, 'week'), (20, 'sterling'), (20, 'yen'), (20, 'share'), (20, 'ftse'), (20, 'pound'), (20, "sterling's"), (20, 'bitcoin'), (20, 'reuters'), (20, 'american'), (20, 'crude'), (21, 'federal'), (21, "britain's"), (21, 'billion'), (21, 'primar'), (21, 'presidential'), (21, 'trillion'), (21, 'stockpile'), (21, 'theresa'), (21, 'pesar'), (21, 'good'), (22, 'bank'), (22, 'euro'), (22, 'european'), (22, 'central'), (22, 'policy'), (22, 'dollar'), (22, 'thursday'), (22, 'zone'), (22, 'low'), (22, 'ease'), (23, 'dollar'), (23, 'month'), (23, 'week'), (23, 'euro'), (23, 'sterling'), (23, 'year'), (23, 'u.s'), (23, 'fall'), (23, 'low'), (23, 'monday'), (24, 'low'), (24, 'high'), (24, 'saudi'), (24, 'opec'), (24, 'past'), (24, 'cap\xc3\xadtulo'), (24, 'production'), (24, 'collapse'), (24, 'produce'), (24, 'regain')]

# %%
topic_terms.iloc[:,[0,1]].head() #['topic','term']
# Out:
#    topic      term
# 0      0  investor
# 1      0  national
# 2      0      opec
# 3      0  capítulo
# 4      0     swiss

# %%
#similar_by_cluster = defaultdict(list)
#for a, b in zip(cluster_groups, ret2.columns):
#       similar_by_cluster[a].append(b)

# %%
#similar_by_cluster = defaultdict(list)
similar_by_cluster = defaultdict(list)
for a,b in zip(topic, term):
    similar_by_cluster[a].append(b)

# %%
similar_by_cluster
# Out:
# defaultdict(list,
#             {0: ['investor',
#               'national',
#               'opec',
#               'cap\xc3\xadtulo',
#               'swiss',
#               'member',
#               'scrap',
#               'revive',
#               'fight',
#               'snb'],
#              1: ['friday',
#               'wednesday',
#               'thursday',
#               'tuesday',
#               'monday',
#               'saturday',
#               'sunday',
#               'strategist',
#               'road',
#               'prove'],
#              2: ['euro',
#               'zone',
#               'debt',
#               'crisis',
#               'government',
#               'bond',
#               'greece',
#               'investor',
#               'market',
#               'european'],
#              3: ['bank',
#               'union',
#               'share',
#               "bank's",
#               'company',
#               'opec',
#               'group',
#               'producer',
#               'banker',
#               'glut'],
#              4: ['yen',
#               'dollar',
#               'bank',
#               'monetary',
#               'japanese',
#               'japan',
#               'policy',
#               'minister',
#               'currency',
#               'low'],
#              5: ['u.s',
#               'britain',
#               'uk',
#               'union',
#               'export',
#               'mine',
#               'russian',
#               'brexit',
#               'energy',
#               'metal'],
#              6: ['dollar',
#               'ftse',
#               'share',
#               'brent',
#               'weight',
#               'bitcoin',
#               'barrel',
#               'international',
#               'crude',
#               'miner'],
#              7: ['interest',
#               'credit',
#               'top',
#               'downgrade',
#               'sovereign',
#               'iran',
#               "moody's",
#               'lend',
#               'telecom',
#               'deposit'],
#              8: ['rate',
#               'bill',
#               'pick',
#               'barrel',
#               'issue',
#               'retailer',
#               'hsbc',
#               'telecom',
#               'development',
#               'direct'],
#              9: ['dollar',
#               'show',
#               'sterling',
#               'u.s',
#               'month',
#               'datar',
#               'euro',
#               'rise',
#               'year',
#               'expect'],
#              10: ['yuan',
#               'exchange',
#               'foreign',
#               "china's",
#               'bank',
#               'currency',
#               'central',
#               'chino',
#               'market',
#               'trade'],
#              11: ['primar',
#               'market',
#               'theresa',
#               'referendum',
#               'trough',
#               "may's",
#               'parliament',
#               'narrow',
#               'aid',
#               'parliamentary'],
#              12: ['european',
#               'index',
#               'top',
#               'janet',
#               'chair',
#               'yellen',
#               'world',
#               'treasury',
#               'trump',
#               "reserve's"],
#              13: ['stock',
#               'u.s',
#               'global',
#               'market',
#               'equity',
#               'investor',
#               'fall',
#               'rise',
#               'price',
#               'world'],
#              14: ['datar',
#               'president',
#               'report',
#               'sanction',
#               'poll',
#               'donald',
#               'survey',
#               'avert',
#               'result',
#               'announce'],
#              15: ['fall',
#               'high',
#               'languish',
#               'slide',
#               'wait',
#               'skid',
#               'plunge',
#               'million',
#               'wallow',
#               'sink'],
#              16: ['dollar',
#               'u.s',
#               'week',
#               'high',
#               'month',
#               'euro',
#               'basket',
#               'currency',
#               'friday',
#               'year'],
#              17: ['reservar',
#               "reserve's",
#               'billion',
#               'regulator',
#               'midpoint',
#               'finance',
#               'account',
#               'meeting',
#               'primar',
#               'executive'],
#              18: ['currency',
#               'financial',
#               'share',
#               'equity',
#               'theresa',
#               'security',
#               "currency's",
#               'source',
#               'europe',
#               'executive'],
#              19: ['bank',
#               'rate',
#               'interest',
#               'sterling',
#               'england',
#               'rise',
#               'low',
#               'dollar',
#               'high',
#               'week'],
#              20: ['sterling',
#               'yen',
#               'share',
#               'ftse',
#               'pound',
#               "sterling's",
#               'bitcoin',
#               'reuters',
#               'american',
#               'crude'],
#              21: ['federal',
#               "britain's",
#               'billion',
#               'primar',
#               'presidential',
#               'trillion',
#               'stockpile',
#               'theresa',
#               'pesar',
#               'good'],
#              22: ['bank',
#               'euro',
#               'european',
#               'central',
#               'policy',
#               'dollar',
#               'thursday',
#               'zone',
#               'low',
#               'ease'],
#              23: ['dollar',
#               'month',
#               'week',
#               'euro',
#               'sterling',
#               'year',
#               'u.s',
#               'fall',
#               'low',
#               'monday'],
#              24: ['low',
#               'high',
#               'saudi',
#               'opec',
#               'past',
#               'cap\xc3\xadtulo',
#               'production',
#               'collapse',
#               'produce',
#               'regain']})

# %%
df['topic'] = doc_topics['topic']

# %%
df.head()
# Out:
#          Date Timestamp                                            excerpt  \
# 0  2018-11-27  02:19:00  The U.S. dollar gained on Tuesday after Federa...
# 1  2018-11-27  10:30:00  Sterling slumped against the dollar and the eu...
# 2  2018-11-28  09:25:00  Sterling gave up most of its earlier gains and...
# 3  2018-11-28  01:50:00  The dollar tumbled from two-week highs on Wedn...
# 4  2018-11-29  09:52:00  The pound fell towards a two-week low on Thurs...
#
#                                                 link  page  \
# 0  https://uk.reuters.com/article/uk-global-forex...     1
# 1  https://uk.reuters.com/article/uk-britain-ster...     1
# 2  https://uk.reuters.com/article/uk-britain-ster...     1
# 3  https://uk.reuters.com/article/uk-global-forex...     1
# 4  https://uk.reuters.com/article/uk-britain-ster...     1
#
#                                                 post  \
# 0  NEW YORK (Reuters) - The U.S. dollar gained on...
# 1  LONDON (Reuters) - Sterling slumped against th...
# 2  LONDON (Reuters) - Sterling gave up most of it...
# 3  NEW YORK (Reuters) - The dollar tumbled from t...
# 4  LONDON (Reuters) - The pound fell towards a tw...
#
#                                                title  topic
# 0  Dollar gains as Fed's Clarida backs further ra...     12
# 1       Sterling slides with UK Brexit vote in doubt      2
# 2  Sterling erases earlier gains after central ba...     19
# 3  Dollar drops as Fed's Powell says rates near n...     19
# 4  Sterling heads towards two-week lows as Brexit...     19

# %%
#df[df.topic == 20]
# Out:
# Empty DataFrame
# Columns: [Date, Timestamp, excerpt, link, page, post, title, topic, term]
# Index: []

# %%
#df.topic
#df = df.drop('term', 1)

# %%
list = []
list.append("d")
print(list)
list[0]
# Out:
# ['d']
# 'd'

# %%
list = []
for i in df.topic:
    list.append(str(similar_by_cluster[i]))
    #df['term'][i]= str(similar_by_cluster[i])

# %%
df["term"] = list

# %%
df.head()
# Out:
#          Date Timestamp                                            excerpt  \
# 0  2018-11-27  02:19:00  The U.S. dollar gained on Tuesday after Federa...
# 1  2018-11-27  10:30:00  Sterling slumped against the dollar and the eu...
# 2  2018-11-28  09:25:00  Sterling gave up most of its earlier gains and...
# 3  2018-11-28  01:50:00  The dollar tumbled from two-week highs on Wedn...
# 4  2018-11-29  09:52:00  The pound fell towards a two-week low on Thurs...
#
#                                                 link  page  \
# 0  https://uk.reuters.com/article/uk-global-forex...     1
# 1  https://uk.reuters.com/article/uk-britain-ster...     1
# 2  https://uk.reuters.com/article/uk-britain-ster...     1
# 3  https://uk.reuters.com/article/uk-global-forex...     1
# 4  https://uk.reuters.com/article/uk-britain-ster...     1
#
#                                                 post  \
# 0  NEW YORK (Reuters) - The U.S. dollar gained on...
# 1  LONDON (Reuters) - Sterling slumped against th...
# 2  LONDON (Reuters) - Sterling gave up most of it...
# 3  NEW YORK (Reuters) - The dollar tumbled from t...
# 4  LONDON (Reuters) - The pound fell towards a tw...
#
#                                                title  topic  \
# 0  Dollar gains as Fed's Clarida backs further ra...     12
# 1       Sterling slides with UK Brexit vote in doubt      2
# 2  Sterling erases earlier gains after central ba...     19
# 3  Dollar drops as Fed's Powell says rates near n...     19
# 4  Sterling heads towards two-week lows as Brexit...     19
#
#                                                 term
# 0  ['european', 'index', 'top', 'janet', 'chair',...
# 1  ['euro', 'zone', 'debt', 'crisis', 'government...
# 2  ['bank', 'rate', 'interest', 'sterling', 'engl...
# 3  ['bank', 'rate', 'interest', 'sterling', 'engl...
# 4  ['bank', 'rate', 'interest', 'sterling', 'engl...

# %%
df.to_csv('./data/reuters_topic_modeling.csv', index=False)

# %% [markdown]
# ## grab output files from sentiment

# %%
topic_terms = pd.read_csv('./data/excerpt-sentiment.txt', header = None)

# %%
topic_terms.columns = ['output','line','sentiment','mixed','negative','neutral','positive']

# %%
#topic_terms = topic_terms.drop('output', 1)
#topic_terms = topic_terms.drop('line', 1)

# %%
#topic_terms = topic_terms.drop(range(10200,10203),0)

# %%
topic_terms['sentiment'] = topic_terms['sentiment'].apply(lambda x: re.sub('"Sentiment":', '', x))
topic_terms['mixed'] = topic_terms['mixed'].apply(lambda x: re.sub('"SentimentScore": {"Mixed":', '', x))
topic_terms['negative'] = topic_terms['negative'].apply(lambda x: re.sub('"Negative":', '', x))
topic_terms['neutral'] = topic_terms['neutral'].apply(lambda x: re.sub('"Neutral":', '', x))
topic_terms['positive'] = topic_terms['positive'].apply(lambda x: re.sub('"Positive":', '', x))

# %%
topic_terms['sentiment'] = topic_terms['sentiment'].apply(lambda x: re.sub('"', '', x))
topic_terms['positive'] = topic_terms['positive'].apply(lambda x: re.sub('}}', '', x))

# %%
range(10200,10202)
# Out:
# [10200, 10201]

# %%
topic_terms.groupby('sentiment').count()
# Out:
#             mixed  negative  neutral  positive
# sentiment
#   MIXED         8         8        8         8
#   NEGATIVE    704       704      704       704
#   NEUTRAL    9436      9436     9436      9436
#   POSITIVE     52        52       52        52

# %%
topic_terms.head(20)
# Out:
#     sentiment                     mixed                 negative  \
# 0     NEUTRAL      0.003546264488250017     0.006710795219987631
# 1     NEUTRAL      0.008189366199076176       0.3202889561653137
# 2     NEUTRAL      0.008085686713457108      0.06420525163412094
# 3     NEUTRAL     0.0006543741328641772     0.004814448766410351
# 4     NEUTRAL     0.0038918505888432264      0.05068398267030716
# 5     NEUTRAL      0.004253205843269825      0.12699416279792786
# 6     NEUTRAL     0.0039678472094237804     0.030410561710596085
# 7     NEUTRAL    0.00023727756342850626    0.0004061247454956174
# 8     NEUTRAL     0.0005289752734825015    0.0032367452513426542
# 9     NEUTRAL      0.005376993212848902     0.021048374474048615
# 10    NEUTRAL     0.0006966232904233038    0.0008452083566226065
# 11    NEUTRAL      0.009963735938072205      0.14801613986492157
# 12    NEUTRAL      0.025538522750139236      0.10721231251955032
# 13    NEUTRAL      0.000863559718709439     0.007239901926368475
# 14    NEUTRAL     0.0021905226167291403      0.01808147318661213
# 15    NEUTRAL       0.00120591651648283     0.004279259592294693
# 16    NEUTRAL    0.00023341755149886012    0.0014917850494384766
# 17    NEUTRAL     0.0011885794810950756      0.03354599326848984
# 18    NEUTRAL    0.00024419493274763227    0.0011464189738035202
# 19    NEUTRAL     0.0016341230366379023     0.005972214043140411
#
#                  neutral                 positive
# 0     0.9880415201187134    0.0017014214536175132
# 1      0.666081964969635      0.00543964933604002
# 2     0.9212760329246521     0.006432929541915655
# 3     0.9928760528564453    0.0016551942098885775
# 4      0.942244291305542    0.0031799226999282837
# 5     0.8649519681930542    0.0038006799295544624
# 6     0.9502358436584473     0.015385725535452366
# 7     0.9981526732444763    0.0012039742432534695
# 8     0.9956300258636475    0.0006042591412551701
# 9     0.9595285058021545     0.014046105556190014
# 10    0.9919267892837524     0.006531316787004471
# 11    0.8387315273284912    0.0032886259723454714
# 12    0.5440853834152222       0.3231637477874756
# 13    0.9880237579345703    0.0038727535866200924
# 14    0.9657918214797974     0.013936239294707775
# 15    0.9654332399368286     0.029081594198942184
# 16     0.997687816619873    0.0005869728047400713
# 17    0.9647775888442993    0.0004878514155279845
# 18    0.9961082339286804    0.0025011305697262287
# 19    0.9887785315513611    0.0036151455715298653

# %%
test3 = pd.concat([df, topic_terms], axis=1)
test3.head()
# Out:
#          Date Timestamp                                            excerpt  \
# 0  2018-11-27  02:19:00  The U.S. dollar gained on Tuesday after Federa...
# 1  2018-11-27  10:30:00  Sterling slumped against the dollar and the eu...
# 2  2018-11-28  09:25:00  Sterling gave up most of its earlier gains and...
# 3  2018-11-28  01:50:00  The dollar tumbled from two-week highs on Wedn...
# 4  2018-11-29  09:52:00  The pound fell towards a two-week low on Thurs...
#
#                                                 link  page  \
# 0  https://uk.reuters.com/article/uk-global-forex...     1
# 1  https://uk.reuters.com/article/uk-britain-ster...     1
# 2  https://uk.reuters.com/article/uk-britain-ster...     1
# 3  https://uk.reuters.com/article/uk-global-forex...     1
# 4  https://uk.reuters.com/article/uk-britain-ster...     1
#
#                                                 post  \
# 0  NEW YORK (Reuters) - The U.S. dollar gained on...
# 1  LONDON (Reuters) - Sterling slumped against th...
# 2  LONDON (Reuters) - Sterling gave up most of it...
# 3  NEW YORK (Reuters) - The dollar tumbled from t...
# 4  LONDON (Reuters) - The pound fell towards a tw...
#
#                                                title  topic  \
# 0  Dollar gains as Fed's Clarida backs further ra...     12
# 1       Sterling slides with UK Brexit vote in doubt      2
# 2  Sterling erases earlier gains after central ba...     19
# 3  Dollar drops as Fed's Powell says rates near n...     19
# 4  Sterling heads towards two-week lows as Brexit...     19
#
#                                                 term  sentiment  \
# 0  ['european', 'index', 'top', 'janet', 'chair',...    NEUTRAL
# 1  ['euro', 'zone', 'debt', 'crisis', 'government...    NEUTRAL
# 2  ['bank', 'rate', 'interest', 'sterling', 'engl...    NEUTRAL
# 3  ['bank', 'rate', 'interest', 'sterling', 'engl...    NEUTRAL
# 4  ['bank', 'rate', 'interest', 'sterling', 'engl...    NEUTRAL
#
#                      mixed                negative               neutral  \
# 0     0.003546264488250017    0.006710795219987631    0.9880415201187134
# 1     0.008189366199076176      0.3202889561653137     0.666081964969635
# 2     0.008085686713457108     0.06420525163412094    0.9212760329246521
# 3    0.0006543741328641772    0.004814448766410351    0.9928760528564453
# 4    0.0038918505888432264     0.05068398267030716     0.942244291305542
#
#                   positive
# 0    0.0017014214536175132
# 1      0.00543964933604002
# 2     0.006432929541915655
# 3    0.0016551942098885775
# 4    0.0031799226999282837

# %%
test3.to_csv('./data/reuters_excerpt_NLP_full.csv', index=False)

# %% [markdown]
# ### add post topic modeling

# %%
df2 = pd.read_csv('./data/reuters_post_topic_modeling.csv')

# %%
df2.head()
# Out:
#          Date Timestamp                                            excerpt  \
# 0  2018-11-27  02:19:00  The U.S. dollar gained on Tuesday after Federa...
# 1  2018-11-27  10:30:00  Sterling slumped against the dollar and the eu...
# 2  2018-11-28  09:25:00  Sterling gave up most of its earlier gains and...
# 3  2018-11-28  01:50:00  The dollar tumbled from two-week highs on Wedn...
# 4  2018-11-29  09:52:00  The pound fell towards a two-week low on Thurs...
#
#                                                 link  page  \
# 0  https://uk.reuters.com/article/uk-global-forex...     1
# 1  https://uk.reuters.com/article/uk-britain-ster...     1
# 2  https://uk.reuters.com/article/uk-britain-ster...     1
# 3  https://uk.reuters.com/article/uk-global-forex...     1
# 4  https://uk.reuters.com/article/uk-britain-ster...     1
#
#                                                 post  \
# 0  NEW YORK (Reuters) - The U.S. dollar gained on...
# 1  LONDON (Reuters) - Sterling slumped against th...
# 2  LONDON (Reuters) - Sterling gave up most of it...
# 3  NEW YORK (Reuters) - The dollar tumbled from t...
# 4  LONDON (Reuters) - The pound fell towards a tw...
#
#                                                title  post.topic  \
# 0  Dollar gains as Fed's Clarida backs further ra...          27
# 1       Sterling slides with UK Brexit vote in doubt          19
# 2  Sterling erases earlier gains after central ba...           4
# 3  Dollar drops as Fed's Powell says rates near n...          27
# 4  Sterling heads towards two-week lows as Brexit...          19
#
#                                            post.term
# 0  ['dollar', 'u.s', 'rate', 'federal', 'reservar...
# 1  ['bank', 'rate', 'sterling', 'england', 'inter...
# 2  ['euro', 'zone', 'debt', 'crisis', 'european',...
# 3  ['dollar', 'u.s', 'rate', 'federal', 'reservar...
# 4  ['bank', 'rate', 'sterling', 'england', 'inter...

# %%
test3['post.topic'] = df2['post.topic']
test3['post.term'] = df2['post.term']

# %%
test3.head()
# Out:
#          Date Timestamp                                            excerpt  \
# 0  2018-11-27  02:19:00  The U.S. dollar gained on Tuesday after Federa...
# 1  2018-11-27  10:30:00  Sterling slumped against the dollar and the eu...
# 2  2018-11-28  09:25:00  Sterling gave up most of its earlier gains and...
# 3  2018-11-28  01:50:00  The dollar tumbled from two-week highs on Wedn...
# 4  2018-11-29  09:52:00  The pound fell towards a two-week low on Thurs...
#
#                                                 link  page  \
# 0  https://uk.reuters.com/article/uk-global-forex...     1
# 1  https://uk.reuters.com/article/uk-britain-ster...     1
# 2  https://uk.reuters.com/article/uk-britain-ster...     1
# 3  https://uk.reuters.com/article/uk-global-forex...     1
# 4  https://uk.reuters.com/article/uk-britain-ster...     1
#
#                                                 post  \
# 0  NEW YORK (Reuters) - The U.S. dollar gained on...
# 1  LONDON (Reuters) - Sterling slumped against th...
# 2  LONDON (Reuters) - Sterling gave up most of it...
# 3  NEW YORK (Reuters) - The dollar tumbled from t...
# 4  LONDON (Reuters) - The pound fell towards a tw...
#
#                                                title  topic  \
# 0  Dollar gains as Fed's Clarida backs further ra...     12
# 1       Sterling slides with UK Brexit vote in doubt      2
# 2  Sterling erases earlier gains after central ba...     19
# 3  Dollar drops as Fed's Powell says rates near n...     19
# 4  Sterling heads towards two-week lows as Brexit...     19
#
#                                                 term  sentiment  \
# 0  ['european', 'index', 'top', 'janet', 'chair',...    NEUTRAL
# 1  ['euro', 'zone', 'debt', 'crisis', 'government...    NEUTRAL
# 2  ['bank', 'rate', 'interest', 'sterling', 'engl...    NEUTRAL
# 3  ['bank', 'rate', 'interest', 'sterling', 'engl...    NEUTRAL
# 4  ['bank', 'rate', 'interest', 'sterling', 'engl...    NEUTRAL
#
#                      mixed                negative               neutral  \
# 0     0.003546264488250017    0.006710795219987631    0.9880415201187134
# 1     0.008189366199076176      0.3202889561653137     0.666081964969635
# 2     0.008085686713457108     0.06420525163412094    0.9212760329246521
# 3    0.0006543741328641772    0.004814448766410351    0.9928760528564453
# 4    0.0038918505888432264     0.05068398267030716     0.942244291305542
#
#                   positive  post.topic  \
# 0    0.0017014214536175132          27
# 1      0.00543964933604002          19
# 2     0.006432929541915655           4
# 3    0.0016551942098885775          27
# 4    0.0031799226999282837          19
#
#                                            post.term
# 0  ['dollar', 'u.s', 'rate', 'federal', 'reservar...
# 1  ['bank', 'rate', 'sterling', 'england', 'inter...
# 2  ['euro', 'zone', 'debt', 'crisis', 'european',...
# 3  ['dollar', 'u.s', 'rate', 'federal', 'reservar...
# 4  ['bank', 'rate', 'sterling', 'england', 'inter...

# %%
test3.to_csv('./data/reuters_excerpt_post_NLP_full.csv', index=False)
