# %% [markdown]
# # Reuters Archives - Amazon Comprehend (NLP and Text Analytics)

# %% [markdown]
# **Objectives:**
# 1. Use Amazon Comprehend for Topic Modeling and Sentiment Analysis
# https://docs.aws.amazon.com/comprehend/latest/dg/getting-started.html
# - Sentiment Analysis - https://docs.aws.amazon.com/comprehend/latest/dg/how-sentiment.html
# - Topic Modeling - https://docs.aws.amazon.com/comprehend/latest/dg/topic-modeling.html

# %% [markdown]
# - The Reuters dataset used here "reuters_data.csv" was web scraped from https://uk.reuters.com/news/archive/GCA-ForeignExchange on Dec 2, 2018. It contains...
# - articles from 2010-05-17 to 2018-11-30
# - 10,200 total articles
# - Index([u'Date', u'Timestamp', u'excerpt', u'link', u'page', u'post', u'title'], dtype='object')

# %%
import boto3
import botocore

# %%
Bucket = "capstoneproject-770851433061"
Key = "reuters_data_with_location.csv" #"Name of the file in S3 that you want to download"
outPutName = "reuters_data_with_location.csv" #The name you want to save after we download from s3
s3 = boto3.resource('s3')
try:
    s3.Bucket(Bucket).download_file(Key, outPutName)
except botocore.exceptions.ClientError as e:
    if e.response['Error']['Code'] == "404":
        print("The object does not exist.")
    else:
        raise

# %%
python -m pip install --user nltk #python2

# %% [markdown]
# # Objective 1. Topic Modeling and Sentiment Analysis on Article Excerpts

# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd
df = pd.read_csv('./data/reuters_data.csv')

# %%
df.post[1]
# Out:
# 'LONDON (Reuters) - Sterling slumped against the dollar and the euro on Tuesday as doubts grew about whether British Prime Minister Theresa May can get a Brexit agreement through a divided parliament.  May began a tour of the United Kingdom to drum up support for her Brexit divorce deal with the European Union but her deputy said parliament might reject it if asked to vote on it now. May\xa1\xa6s attempts to win over critics in her Conservative and opposition parties in order to get her deal approved are seen by investors as increasingly fraught.   \xa1\xa7The failure of the pound to rally on recent positive developments suggest the market is pricing in that the deal won\xa1\xa6t pass the first time in parliament,\xa1\xa8 said Lee Hardman, a currency analyst at MUFG. \xa1\xa7The pound will likely trade with increased volatility during the next two weeks.\xa1\xa8 Against the dollar, the British currency fell more than half a percent to $1.2730, its lowest level in nearly two weeks. It also fell a third of a percent against a weak euro to 88.87 pence. Sterling\xa1\xa6s losses were compounded by comments from U.S. President Donald Trump that a Brexit deal could hamper trade ties with the United States. \xa1\xa7The comments from Trump and more uncertainty regarding the future trade agreements of the UK following Brexit next year are weighing on the short-term outlook for the pound,\xa1\xa8 said Sebastian Fellechner, an analyst at DZ Bank.  The pound on Tuesday broke through a key support level of around $1.2770, which it had managed to stay above in the last few trading sessions. Positioning also offered little respite for the British currency after a large chunk of short positions were whittled away in recent weeks, leaving the pound more vulnerable to losses.'

# %%
#get excerpts
reuters_post = df.post[:]
reuters_post.head()
# Out:
# 0    NEW YORK (Reuters) - The U.S. dollar gained on...
# 1    LONDON (Reuters) - Sterling slumped against th...
# 2    LONDON (Reuters) - Sterling gave up most of it...
# 3    NEW YORK (Reuters) - The dollar tumbled from t...
# 4    LONDON (Reuters) - The pound fell towards a tw...
# Name: post, dtype: object

# %%
#reuters_excerpt.to_csv('./data/reuters_excerpt.csv')

# %%
with open("reuters_post.txt", "w") as my_output_file:
    [my_output_file.write("".join(row)+'\n') for row in reuters_post]
my_output_file.close()
#copy and paste to UTF

# %%
#import io
#with open("reuters_excerpt.txt",'r') as f:
#    text = f.read()
# process Unicode text
#with io.open("reuters_excerpt_utf.txt",'w',encoding='utf8') as f:
#    f.write(text)

# %% [markdown]
# ## Submit to Amazon Comprehend for Topic Modeling and Sentiment
# ### grab output files from Topic Modeling

# %%
topic_terms = pd.read_csv('./data/post-topic-terms.csv')
doc_topics = pd.read_csv('./data/post-doc-topics.csv')

# %%
topic_terms.head()
# Out:
#    topic      term    weight
# 0      0      year  0.023462
# 1      0      show  0.017193
# 2      0      poll  0.015251
# 3      0   reuters  0.014388
# 4      0  european  0.014177

# %%
doc_topics.head()
# Out:
#                      docname  topic  proportion
# 0    reuters_postt_utf.txt:6     16         1.0
# 1   reuters_postt_utf.txt:41     14         1.0
# 2   reuters_postt_utf.txt:76      1         1.0
# 3  reuters_postt_utf.txt:111      0         1.0
# 4  reuters_postt_utf.txt:146      4         1.0

# %%
import re
doc_topics['docname'] = doc_topics['docname'].apply(lambda x: re.sub('reuters_postt_utf.txt:', '', x))
doc_topics.docname = pd.to_numeric(doc_topics.docname)
doc_topics = doc_topics.sort_values('docname')

# %%
doc_topics= doc_topics.reset_index()
doc_topics.head()
# Out:
#    index  docname  topic  proportion
# 0   3204        0     27         1.0
# 1   8159        1     19         1.0
# 2   9325        2      4         1.0
# 3    583        3     27         1.0
# 4   3496        4     19         1.0

# %%
len(topic_terms.topic.unique())
# Out:
# 30

# %%
len(doc_topics.topic.unique())
#30 topics but only 22 selected
# Out:
# 22

# %%
doc_topics.groupby('topic')["proportion"].count()
# Out:
# topic
# 0     1231
# 1     1163
# 2       53
# 3       35
# 4     1402
# 5     2048
# 6       46
# 7       24
# 8        8
# 9        8
# 10       1
# 11       6
# 12     849
# 13     595
# 14     456
# 15      11
# 16     528
# 17     425
# 18      12
# 19     650
# 26     241
# 27     408
# Name: proportion, dtype: int64

# %%
from collections import defaultdict

# %%
#cluster_groups = kmeans.predict(ret2.T)
#set(cluster_groups)
#print(cluster_groups)
#print(list(zip(cluster_groups, ret2.columns)))

# %%
topic = topic_terms['topic']
term = topic_terms['term']
#set(list(topic))
#print(list(topic))
print (list(zip(topic, term)))
# Out:
# [(0, 'year'), (0, 'show'), (0, 'poll'), (0, 'reuters'), (0, 'european'), (0, 'month'), (0, 'currency'), (0, 'union'), (0, 'sterling'), (0, 'leave'), (1, 'yen'), (1, 'dollar'), (1, 'japanese'), (1, 'safe'), (1, 'currency'), (1, 'haven'), (1, 'japan'), (1, 'low'), (1, 'minister'), (1, 'monday'), (2, 'market'), (2, 'primar'), (2, 'referendum'), (2, 'york'), (2, 'theresa'), (2, 'centrar'), (2, 'border'), (2, 'consecutive'), (2, 'campaign'), (2, 'sideline'), (3, 'friday'), (3, 'thursday'), (3, 'wednesday'), (3, 'tuesday'), (3, 'monday'), (3, 'saturday'), (3, 'sunday'), (3, 'prove'), (3, 'road'), (3, 'story'), (4, 'euro'), (4, 'zone'), (4, 'debt'), (4, 'crisis'), (4, 'european'), (4, 'investor'), (4, 'greece'), (4, 'government'), (4, 'monday'), (4, 'bond'), (5, 'u.s'), (5, 'stock'), (5, 'global'), (5, 'bond'), (5, 'market'), (5, 'high'), (5, 'rise'), (5, 'investor'), (5, 'equity'), (5, 'european'), (6, 'bank'), (6, 'union'), (6, 'share'), (6, "bank's"), (6, 'company'), (6, 'group'), (6, 'banker'), (6, 'ukraine'), (6, 'underperform'), (6, 'russia'), (7, 'dollar'), (7, 'ftse'), (7, 'share'), (7, 'brent'), (7, 'bitcoin'), (7, 'crude'), (7, 'inventory'), (7, 'weight'), (7, 'miner'), (7, 'barrel'), (8, 'central'), (8, 'union'), (8, 'england'), (8, "union's"), (8, 'deutsche'), (8, 'national'), (8, 'euribor'), (8, 'inventory'), (8, 'rig'), (8, 'commission'), (9, 'u.s'), (9, 'uk'), (9, 'britain'), (9, 'brexit'), (9, 'energy'), (9, 'mine'), (9, 'russian'), (9, 'metal'), (9, 'union'), (9, 'company'), (10, 'fall'), (10, 'rise'), (10, 'jump'), (10, 'climb'), (10, 'saudi'), (10, 'plunge'), (10, 'dip'), (10, 'million'), (10, 'turn'), (10, 'producer'), (11, 'high'), (11, 'iran'), (11, 'opec'), (11, 'agreement'), (11, 'industry'), (11, 'barrel'), (11, 'slash'), (11, 'great'), (11, 'ramp'), (11, 'calm'), (12, 'exchange'), (12, 'foreign'), (12, 'market'), (12, 'yuan'), (12, "china's"), (12, 'billion'), (12, 'regulator'), (12, 'trade'), (12, 'chino'), (12, 'currency'), (13, 'dollar'), (13, 'sterling'), (13, 'u.s'), (13, 'show'), (13, 'euro'), (13, 'month'), (13, 'fall'), (13, 'datar'), (13, 'economic'), (13, 'expect'), (14, 'dollar'), (14, 'u.s'), (14, 'week'), (14, 'high'), (14, 'basket'), (14, 'major'), (14, 'month'), (14, 'currency'), (14, 'euro'), (14, 'friday'), (15, 'share'), (15, 'world'), (15, 'monetary'), (15, 'bond'), (15, 'union'), (15, 'fund'), (15, 'international'), (15, 'bet'), (15, 'focus'), (15, 'hedge'), (16, 'bank'), (16, 'dollar'), (16, 'euro'), (16, 'monetary'), (16, 'u.s'), (16, 'central'), (16, 'policy'), (16, 'low'), (16, 'yen'), (16, 'month'), (17, 'bank'), (17, 'yuan'), (17, 'central'), (17, 'dollar'), (17, "china's"), (17, 'currency'), (17, 'chino'), (17, 'foreign'), (17, 'exchange'), (17, 'midpoint'), (18, 'european'), (18, 'index'), (18, 'world'), (18, 'global'), (18, 'top'), (18, 'ftse'), (18, 'oil'), (18, 'janet'), (18, 'energy'), (18, 'chair'), (19, 'bank'), (19, 'rate'), (19, 'sterling'), (19, 'england'), (19, 'interest'), (19, 'low'), (19, 'rise'), (19, 'month'), (19, 'week'), (19, 'dollar'), (20, 'currency'), (20, 'financial'), (20, 'equity'), (20, 'security'), (20, "currency's"), (20, 'regulator'), (20, 'theresa'), (20, 'capital'), (20, 'executive'), (20, 'europe'), (21, 'datar'), (21, 'president'), (21, 'sanction'), (21, 'avert'), (21, 'default'), (21, 'announce'), (21, 'turkey'), (21, 'fundamental'), (21, 'scholar'), (21, 'strange'), (22, 'sterling'), (22, 'yen'), (22, 'share'), (22, 'ftse'), (22, "sterling's"), (22, 'oil'), (22, 'stock'), (22, 'crude'), (22, 'pound'), (22, 'american'), (23, 'reservar'), (23, "reserve's"), (23, 'exchange'), (23, 'regulator'), (23, 'minister'), (23, 'committee'), (23, 'bill'), (23, 'primar'), (23, 'operator'), (23, 'platform'), (24, 'federal'), (24, 'exchange'), (24, 'primar'), (24, 'country'), (24, 'bloc'), (24, 'theresa'), (24, 'membership'), (24, 'minister'), (24, 'exit'), (24, 'bill'), (25, 'rate'), (25, 'index'), (25, 'foreign'), (25, 'opec'), (25, 'bill'), (25, 'company'), (25 ...

# %%
topic_terms.iloc[:,[0,1]].head() #['topic','term']
# Out:
#    topic      term
# 0      0      year
# 1      0      show
# 2      0      poll
# 3      0   reuters
# 4      0  european

# %%
#similar_by_cluster = defaultdict(list)
#for a, b in zip(cluster_groups, ret2.columns):
#       similar_by_cluster[a].append(b)

# %%
#similar_by_cluster = defaultdict(list)
similar_by_cluster = defaultdict(list)
for a,b in zip(topic, term):
    similar_by_cluster[a].append(b)

# %%
similar_by_cluster
# Out:
# defaultdict(list,
#             {0: ['year',
#               'show',
#               'poll',
#               'reuters',
#               'european',
#               'month',
#               'currency',
#               'union',
#               'sterling',
#               'leave'],
#              1: ['yen',
#               'dollar',
#               'japanese',
#               'safe',
#               'currency',
#               'haven',
#               'japan',
#               'low',
#               'minister',
#               'monday'],
#              2: ['market',
#               'primar',
#               'referendum',
#               'york',
#               'theresa',
#               'centrar',
#               'border',
#               'consecutive',
#               'campaign',
#               'sideline'],
#              3: ['friday',
#               'thursday',
#               'wednesday',
#               'tuesday',
#               'monday',
#               'saturday',
#               'sunday',
#               'prove',
#               'road',
#               'story'],
#              4: ['euro',
#               'zone',
#               'debt',
#               'crisis',
#               'european',
#               'investor',
#               'greece',
#               'government',
#               'monday',
#               'bond'],
#              5: ['u.s',
#               'stock',
#               'global',
#               'bond',
#               'market',
#               'high',
#               'rise',
#               'investor',
#               'equity',
#               'european'],
#              6: ['bank',
#               'union',
#               'share',
#               "bank's",
#               'company',
#               'group',
#               'banker',
#               'ukraine',
#               'underperform',
#               'russia'],
#              7: ['dollar',
#               'ftse',
#               'share',
#               'brent',
#               'bitcoin',
#               'crude',
#               'inventory',
#               'weight',
#               'miner',
#               'barrel'],
#              8: ['central',
#               'union',
#               'england',
#               "union's",
#               'deutsche',
#               'national',
#               'euribor',
#               'inventory',
#               'rig',
#               'commission'],
#              9: ['u.s',
#               'uk',
#               'britain',
#               'brexit',
#               'energy',
#               'mine',
#               'russian',
#               'metal',
#               'union',
#               'company'],
#              10: ['fall',
#               'rise',
#               'jump',
#               'climb',
#               'saudi',
#               'plunge',
#               'dip',
#               'million',
#               'turn',
#               'producer'],
#              11: ['high',
#               'iran',
#               'opec',
#               'agreement',
#               'industry',
#               'barrel',
#               'slash',
#               'great',
#               'ramp',
#               'calm'],
#              12: ['exchange',
#               'foreign',
#               'market',
#               'yuan',
#               "china's",
#               'billion',
#               'regulator',
#               'trade',
#               'chino',
#               'currency'],
#              13: ['dollar',
#               'sterling',
#               'u.s',
#               'show',
#               'euro',
#               'month',
#               'fall',
#               'datar',
#               'economic',
#               'expect'],
#              14: ['dollar',
#               'u.s',
#               'week',
#               'high',
#               'basket',
#               'major',
#               'month',
#               'currency',
#               'euro',
#               'friday'],
#              15: ['share',
#               'world',
#               'monetary',
#               'bond',
#               'union',
#               'fund',
#               'international',
#               'bet',
#               'focus',
#               'hedge'],
#              16: ['bank',
#               'dollar',
#               'euro',
#               'monetary',
#               'u.s',
#               'central',
#               'policy',
#               'low',
#               'yen',
#               'month'],
#              17: ['bank',
#               'yuan',
#               'central',
#               'dollar',
#               "china's",
#               'currency',
#               'chino',
#               'foreign',
#               'exchange',
#               'midpoint'],
#              18: ['european',
#               'index',
#               'world',
#               'global',
#               'top',
#               'ftse',
#               'oil',
#               'janet',
#               'energy',
#               'chair'],
#              19: ['bank',
#               'rate',
#               'sterling',
#               'england',
#               'interest',
#               'low',
#               'rise',
#               'month',
#               'week',
#               'dollar'],
#              20: ['currency',
#               'financial',
#               'equity',
#               'security',
#               "currency's",
#               'regulator',
#               'theresa',
#               'capital',
#               'executive',
#               'europe'],
#              21: ['datar',
#               'president',
#               'sanction',
#               'avert',
#               'default',
#               'announce',
#               'turkey',
#               'fundamental',
#               'scholar',
#               'strange'],
#              22: ['sterling',
#               'yen',
#               'share',
#               'ftse',
#               "sterling's",
#               'oil',
#               'stock',
#               'crude',
#               'pound',
#               'american'],
#              23: ['reservar',
#               "reserve's",
#               'exchange',
#               'regulator',
#               'minister',
#               'committee',
#               'bill',
#               'primar',
#               'operator',
#               'platform'],
#              24: ['federal',
#               'exchange',
#               'primar',
#               'country',
#               'bloc',
#               'theresa',
#               'membership',
#               'minister',
#               'exit',
#               'bill'],
#              25: ['rate',
#               'index',
#               'foreign',
#               'opec',
#               'bill',
#               'company',
#               'issue',
#               'production',
#               'state',
#               'exposure'],
#              26: ['bank',
#               'swiss',
#               'franc',
#               'currency',
#               'central',
#               'national',
#               'euro',
#               'thursday',
#               'year',
#               'cap\xc3\xadtulo'],
#              27: ['dollar',
#               'u.s',
#               'rate',
#               'federal',
#               'reservar',
#               'interest',
#               'rise',
#               'year',
#               'raise',
#               'week'],
#              28: ['top',
#               'foreign',
#               'swiss',
#               'economy',
#               'hike',
#               'raise',
#               'franc',
#               'national',
#               'cut',
#               'chairman'],
#              29: ['interest',
#               'index',
#               'state',
#               'credit',
#               'opec',
#               'debt',
#               'unite',
#               'cost',
#               'company',
#               'hedge']})

# %%
df['post.topic'] = doc_topics['topic']

# %%
df.head()
# Out:
#          Date Timestamp                                            excerpt  \
# 0  2018-11-27  02:19:00  The U.S. dollar gained on Tuesday after Federa...
# 1  2018-11-27  10:30:00  Sterling slumped against the dollar and the eu...
# 2  2018-11-28  09:25:00  Sterling gave up most of its earlier gains and...
# 3  2018-11-28  01:50:00  The dollar tumbled from two-week highs on Wedn...
# 4  2018-11-29  09:52:00  The pound fell towards a two-week low on Thurs...
#
#                                                 link  page  \
# 0  https://uk.reuters.com/article/uk-global-forex...     1
# 1  https://uk.reuters.com/article/uk-britain-ster...     1
# 2  https://uk.reuters.com/article/uk-britain-ster...     1
# 3  https://uk.reuters.com/article/uk-global-forex...     1
# 4  https://uk.reuters.com/article/uk-britain-ster...     1
#
#                                                 post  \
# 0  NEW YORK (Reuters) - The U.S. dollar gained on...
# 1  LONDON (Reuters) - Sterling slumped against th...
# 2  LONDON (Reuters) - Sterling gave up most of it...
# 3  NEW YORK (Reuters) - The dollar tumbled from t...
# 4  LONDON (Reuters) - The pound fell towards a tw...
#
#                                                title  post.topic
# 0  Dollar gains as Fed's Clarida backs further ra...          27
# 1       Sterling slides with UK Brexit vote in doubt          19
# 2  Sterling erases earlier gains after central ba...           4
# 3  Dollar drops as Fed's Powell says rates near n...          27
# 4  Sterling heads towards two-week lows as Brexit...          19

# %%
#df.topic
#df = df.drop('term', 1)

# %%
list = []
list.append("d")
print(list)
list[0]
# Out:
# ['d']
# 'd'

# %%
list = []
for i in df.topic:
    list.append(str(similar_by_cluster[i]))
    #df['term'][i]= str(similar_by_cluster[i])

# %%
df["post.term"] = list

# %%
df.head()
# Out:
#          Date Timestamp                                            excerpt  \
# 0  2018-11-27  02:19:00  The U.S. dollar gained on Tuesday after Federa...
# 1  2018-11-27  10:30:00  Sterling slumped against the dollar and the eu...
# 2  2018-11-28  09:25:00  Sterling gave up most of its earlier gains and...
# 3  2018-11-28  01:50:00  The dollar tumbled from two-week highs on Wedn...
# 4  2018-11-29  09:52:00  The pound fell towards a two-week low on Thurs...
#
#                                                 link  page  \
# 0  https://uk.reuters.com/article/uk-global-forex...     1
# 1  https://uk.reuters.com/article/uk-britain-ster...     1
# 2  https://uk.reuters.com/article/uk-britain-ster...     1
# 3  https://uk.reuters.com/article/uk-global-forex...     1
# 4  https://uk.reuters.com/article/uk-britain-ster...     1
#
#                                                 post  \
# 0  NEW YORK (Reuters) - The U.S. dollar gained on...
# 1  LONDON (Reuters) - Sterling slumped against th...
# 2  LONDON (Reuters) - Sterling gave up most of it...
# 3  NEW YORK (Reuters) - The dollar tumbled from t...
# 4  LONDON (Reuters) - The pound fell towards a tw...
#
#                                                title  post.topic  \
# 0  Dollar gains as Fed's Clarida backs further ra...          27
# 1       Sterling slides with UK Brexit vote in doubt          19
# 2  Sterling erases earlier gains after central ba...           4
# 3  Dollar drops as Fed's Powell says rates near n...          27
# 4  Sterling heads towards two-week lows as Brexit...          19
#
#                                            post.term
# 0  ['dollar', 'u.s', 'rate', 'federal', 'reservar...
# 1  ['bank', 'rate', 'sterling', 'england', 'inter...
# 2  ['euro', 'zone', 'debt', 'crisis', 'european',...
# 3  ['dollar', 'u.s', 'rate', 'federal', 'reservar...
# 4  ['bank', 'rate', 'sterling', 'england', 'inter...

# %%
df.to_csv('./data/reuters_post_topic_modeling.csv', index=False)

# %% [markdown]
# ## grab output files from sentiment

# %%
topic_terms = pd.read_csv('./data/post_sentiment.txt', header = None)

# %%
topic_terms.columns = ['output','line','sentiment','mixed','negative','neutral','positive']

# %%
topic_terms = topic_terms.drop('output', 1)
topic_terms = topic_terms.drop('line', 1)

# %%
#topic_terms = topic_terms.drop(range(10200,10203),0)

# %%
topic_terms['sentiment'] = topic_terms['sentiment'].apply(lambda x: re.sub('"Sentiment":', '', x))
topic_terms['mixed'] = topic_terms['mixed'].apply(lambda x: re.sub('"SentimentScore": {"Mixed":', '', x))
topic_terms['negative'] = topic_terms['negative'].apply(lambda x: re.sub('"Negative":', '', x))
topic_terms['neutral'] = topic_terms['neutral'].apply(lambda x: re.sub('"Neutral":', '', x))
topic_terms['positive'] = topic_terms['positive'].apply(lambda x: re.sub('"Positive":', '', x))

# %%
topic_terms['sentiment'] = topic_terms['sentiment'].apply(lambda x: re.sub('"', '', x))
topic_terms['positive'] = topic_terms['positive'].apply(lambda x: re.sub('}}', '', x))

# %%
topic_terms.groupby('sentiment').count()
# Out:
#             mixed  negative  neutral  positive
# sentiment
#   MIXED         8         8        8         8
#   NEGATIVE    704       704      704       704
#   NEUTRAL    9436      9436     9436      9436
#   POSITIVE     52        52       52        52

# %%
topic_terms.head(20)
# Out:
#     sentiment                     mixed                 negative  \
# 0     NEUTRAL      0.003546264488250017     0.006710795219987631
# 1     NEUTRAL      0.008189366199076176       0.3202889561653137
# 2     NEUTRAL      0.008085686713457108      0.06420525163412094
# 3     NEUTRAL     0.0006543741328641772     0.004814448766410351
# 4     NEUTRAL     0.0038918505888432264      0.05068398267030716
# 5     NEUTRAL      0.004253205843269825      0.12699416279792786
# 6     NEUTRAL     0.0039678472094237804     0.030410561710596085
# 7     NEUTRAL    0.00023727756342850626    0.0004061247454956174
# 8     NEUTRAL     0.0005289752734825015    0.0032367452513426542
# 9     NEUTRAL      0.005376993212848902     0.021048374474048615
# 10    NEUTRAL     0.0006966232904233038    0.0008452083566226065
# 11    NEUTRAL      0.009963735938072205      0.14801613986492157
# 12    NEUTRAL      0.025538522750139236      0.10721231251955032
# 13    NEUTRAL      0.000863559718709439     0.007239901926368475
# 14    NEUTRAL     0.0021905226167291403      0.01808147318661213
# 15    NEUTRAL       0.00120591651648283     0.004279259592294693
# 16    NEUTRAL    0.00023341755149886012    0.0014917850494384766
# 17    NEUTRAL     0.0011885794810950756      0.03354599326848984
# 18    NEUTRAL    0.00024419493274763227    0.0011464189738035202
# 19    NEUTRAL     0.0016341230366379023     0.005972214043140411
#
#                  neutral                 positive
# 0     0.9880415201187134    0.0017014214536175132
# 1      0.666081964969635      0.00543964933604002
# 2     0.9212760329246521     0.006432929541915655
# 3     0.9928760528564453    0.0016551942098885775
# 4      0.942244291305542    0.0031799226999282837
# 5     0.8649519681930542    0.0038006799295544624
# 6     0.9502358436584473     0.015385725535452366
# 7     0.9981526732444763    0.0012039742432534695
# 8     0.9956300258636475    0.0006042591412551701
# 9     0.9595285058021545     0.014046105556190014
# 10    0.9919267892837524     0.006531316787004471
# 11    0.8387315273284912    0.0032886259723454714
# 12    0.5440853834152222       0.3231637477874756
# 13    0.9880237579345703    0.0038727535866200924
# 14    0.9657918214797974     0.013936239294707775
# 15    0.9654332399368286     0.029081594198942184
# 16     0.997687816619873    0.0005869728047400713
# 17    0.9647775888442993    0.0004878514155279845
# 18    0.9961082339286804    0.0025011305697262287
# 19    0.9887785315513611    0.0036151455715298653

# %% [markdown]
# ## sentiment is the same for excerpt and post!!!
